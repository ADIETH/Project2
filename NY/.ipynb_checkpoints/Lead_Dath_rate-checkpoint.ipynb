# %%
from datetime import datetime
from IPython.display import Image
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib
import numpy as np
import os
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
# Upload image
url = 'https://data.cityofnewyork.us/api/views/jb7j-dtam/rows.csv?accessType=DOWNLOAD'
raw_data = pd.read_csv(url)

# %%
raw_data.head()
# Out:
#    Year                                      Leading Cause Sex  \
# 0  2012                                   All Other Causes   M
# 1  2014                        Diabetes Mellitus (E10-E14)   M
# 2  2008     Diseases of Heart (I00-I09, I11, I13, I20-I51)   M
# 3  2010                                   All Other Causes   M
# 4  2014  Accidents Except Drug Posioning (V01-X39, X43,...   F
#
#        Race Ethnicity Deaths Death Rate Age Adjusted Death Rate
# 0  Not Stated/Unknown     78          .                       .
# 1  Not Stated/Unknown      8          .                       .
# 2  Black Non-Hispanic   2077      244.6                   330.2
# 3  Black Non-Hispanic   1230      144.5                   166.2
# 4  White Non-Hispanic    169       11.9                     7.4

# %%
raw_data.dtypes
# Out:
# Year                        int64
# Leading Cause              object
# Sex                        object
# Race Ethnicity             object
# Deaths                     object
# Death Rate                 object
# Age Adjusted Death Rate    object
# dtype: object

# %%
# identify incomplete rows
raw_data.count()
# Out:
# Year                       1380
# Leading Cause              1380
# Sex                        1380
# Race Ethnicity             1380
# Deaths                     1328
# Death Rate                 1271
# Age Adjusted Death Rate    1271
# dtype: int64

# %%
# Drop all rows with missing information 
raw_data = raw_data.dropna(how='any')
raw_data.count()
# Out:
# Year                       1271
# Leading Cause              1271
# Sex                        1271
# Race Ethnicity             1271
# Deaths                     1271
# Death Rate                 1271
# Age Adjusted Death Rate    1271
# dtype: int64

# %%
df = raw_data

# %%
df.to_csv('cleand_death.csv')

# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import datetime as dt

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func,inspect

# %%
engine = create_engine("sqlite:///db/NY.sqlite")

# %%
# Create the inspector and connect it to the engine
inspector = inspect(engine)

# %%
inspector.get_table_names()
# Out:
# ['cleand_death']

# %%
 # Use Inspector to print the column names and types
columns = inspector.get_columns('cleand_death')
for c in columns:
    print(c['name'], c["type"])
# Out:
# Year INTEGER
# LeadingCause TEXT
# Sex TEXT
# RaceEthnicity TEXT
# Deaths INTEGER
# DeathRate TEXT
# AgeAdjustedDeathRate TEXT
# Field8 INTEGER

# %%
engine.execute('select * from cleand_death').fetchall()
# Out:
# [(2012, 'All Other Causes', 'M', 'Not Stated/Unknown', 78, '.', '.'),
#  (2014, 'Diabetes Mellitus (E10-E14)', 'M', 'Not Stated/Unknown', 8, '.', '.'),
#  (2008, 'Diseases of Heart (I00-I09, I11, I13, I20-I51)', 'M', 'Black Non-Hispanic', 2077, '244.6', '330.2'),
#  (2010, 'All Other Causes', 'M', 'Black Non-Hispanic', 1230, '144.5', '166.2'),
#  (2014, 'Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)', 'F', 'White Non-Hispanic', 169, '11.9', '7.4'),
#  (2011, 'All Other Causes', 'F', 'Other Race/ Ethnicity', 38, '.', '.'),
#  (2011, 'Mental and Behavioral Disorders due to Accidental Poisoning and Other Psychoactive Substance Use (F11-F16, F18-F19, X40-X42, X44)', 'M', 'Hispanic', 145, '12.6', '13'),
#  (2014, 'Influenza (Flu) and Pneumonia (J09-J18)', 'M', 'Not Stated/Unknown', 14, '.', '.'),
#  (2012, 'Influenza (Flu) and Pneumonia (J09-J18)', 'F', 'Not Stated/Unknown', 6, '.', '.'),
# ...

# %%
 # Reflect Database into ORM class
Base = automap_base()
Base.prepare(engine, reflect=True)
Clleand_death = Base.classes.cleand_death
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\sqlalchemy\util\_collections.py in __getattr__(self, key)
#     209         try:
# --> 210             return self._data[key]
#     211         except KeyError:
#
# KeyError: 'cleand_death'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-4c8087d8b520> in <module>()
#       2 Base = automap_base()
#       3 Base.prepare(engine, reflect=True)
# ----> 4 Clleand_death = Base.classes.cleand_death
#
# C:\Anaconda\lib\site-packages\sqlalchemy\util\_collections.py in __getattr__(self, key)
#     210             return self._data[key]
#     211         except KeyError:
# --> 212             raise AttributeError(key)
#     213
#     214     def __contains__(self, key):
#
# ...

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)
cleand_death = Base.classes.cleand_death
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\sqlalchemy\util\_collections.py in __getattr__(self, key)
#     209         try:
# --> 210             return self._data[key]
#     211         except KeyError:
#
# KeyError: 'cleand_death'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-60202b35c0a1> in <module>()
#       3 # reflect the tables
#       4 Base.prepare(engine, reflect=True)
# ----> 5 cleand_death = Base.classes.cleand_death
#
# C:\Anaconda\lib\site-packages\sqlalchemy\util\_collections.py in __getattr__(self, key)
#     210             return self._data[key]
#     211         except KeyError:
# --> 212             raise AttributeError(key)
#     213
#     214     def __contains__(self, key):
#
# ...

# %%
cleand_death = Base.classes.cleand_death
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\sqlalchemy\util\_collections.py in __getattr__(self, key)
#     209         try:
# --> 210             return self._data[key]
#     211         except KeyError:
#
# KeyError: 'cleand_death'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-ad7ce3fc9044> in <module>()
# ----> 1 cleand_death = Base.classes.cleand_death
#
# C:\Anaconda\lib\site-packages\sqlalchemy\util\_collections.py in __getattr__(self, key)
#     210             return self._data[key]
#     211         except KeyError:
# --> 212             raise AttributeError(key)
#     213
#     214     def __contains__(self, key):
#
# AttributeError: cleand_death

# %%
data = engine.execute("select * from cleand_death")

for record in data:
    print(record)
# Out:
# (2012, 'All Other Causes', 'M', 'Not Stated/Unknown', 78, '.', '.')
# (2014, 'Diabetes Mellitus (E10-E14)', 'M', 'Not Stated/Unknown', 8, '.', '.')
# (2008, 'Diseases of Heart (I00-I09, I11, I13, I20-I51)', 'M', 'Black Non-Hispanic', 2077, '244.6', '330.2')
# (2010, 'All Other Causes', 'M', 'Black Non-Hispanic', 1230, '144.5', '166.2')
# (2014, 'Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)', 'F', 'White Non-Hispanic', 169, '11.9', '7.4')
# (2011, 'All Other Causes', 'F', 'Other Race/ Ethnicity', 38, '.', '.')
# (2011, 'Mental and Behavioral Disorders due to Accidental Poisoning and Other Psychoactive Substance Use (F11-F16, F18-F19, X40-X42, X44)', 'M', 'Hispanic', 145, '12.6', '13')
# (2014, 'Influenza (Flu) and Pneumonia (J09-J18)', 'M', 'Not Stated/Unknown', 14, '.', '.')
# (2012, 'Influenza (Flu) and Pneumonia (J09-J18)', 'F', 'Not Stated/Unknown', 6, '.', '.')
# ...

# %%
data.LeadingCause()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-141a992ad71f> in <module>()
# ----> 1 data.LeadingCause()
#
# AttributeError: 'ResultProxy' object has no attribute 'LeadingCause'

# %%
Base.classes.keys()
# Out:
# []

# %%
# Dependency
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine
import os
import json
import pymysql
pymysql.install_as_MySQLdb()
from config import mypass

# %%
df['Race Ethnicity'] = df['Race Ethnicity'].astype('category')
df.head()
# Out:
#    Year                                      Leading Cause Sex  \
# 0  2007                        Diabetes Mellitus (E10-E14)   F
# 1  2007            Influenza (Flu) and Pneumonia (J09-J18)   F
# 2  2007                                   All Other Causes   F
# 3  2007  Accidents Except Drug Posioning (V01-X39, X43,...   F
# 4  2007     Chronic Liver Disease and Cirrhosis (K70, K73)   M
#
#                Race Ethnicity Deaths Death Rate Age Adjusted Death Rate
# 0          Not Stated/Unknown      .          .                       .
# 1          White Non-Hispanic    659       45.9                    23.2
# 2                    Hispanic    820       70.2                    85.6
# 3          Not Stated/Unknown      .          .                       .
# 4  Asian and Pacific Islander     18        3.7                     3.6

# %%
df['Sex'] = df['Sex'].astype('category')

# %%
df['Leading Cause'] = df['Leading Cause'].astype('category')

# %%
# Sort by year
df.sort_values(by='Year', inplace=True)

# Reset index
df.reset_index(drop=True, inplace=True)

df.head()
# Out:
#    Year                                      Leading Cause Sex  \
# 0  2007                        Diabetes Mellitus (E10-E14)   F
# 1  2007            Influenza (Flu) and Pneumonia (J09-J18)   F
# 2  2007                                   All Other Causes   F
# 3  2007  Accidents Except Drug Posioning (V01-X39, X43,...   F
# 4  2007     Chronic Liver Disease and Cirrhosis (K70, K73)   M
#
#                Race Ethnicity Deaths Death Rate Age Adjusted Death Rate
# 0          Not Stated/Unknown      .          .                       .
# 1          White Non-Hispanic    659       45.9                    23.2
# 2                    Hispanic    820       70.2                    85.6
# 3          Not Stated/Unknown      .          .                       .
# 4  Asian and Pacific Islander     18        3.7                     3.6

# %%
ethnicities = list(np.unique(df['Race Ethnicity']))
sex = list(np.unique(df['Sex']))
causes = list(np.unique(df['Cause of Death']))

print 'Race Ethnicity({}):'.format(len(list(np.unique(df['Race Ethnicity'])))), Race Ethnicity
print ""
print 'Sex ({}):'.format(len(list(np.unique(df['Sex'])))), sex
print ""
print 'Leading Cause ({}):'.format(len(list(np.unique(df['Leading Cause'])))), Causes
# Out:
#   File "<ipython-input-2-934a58d6c893>", line 5
#     print 'Race Ethnicity({}):'.format(len(list(np.unique(df['Race Ethnicity'])))), Race Ethnicity
#                               ^
# SyntaxError: invalid syntax

# %%
data
